-- %%
INSERT INTO some_catalog.bronze.customer
INSERT INTO some_catalog.silver.customer
INSERT INTO some_catalog.bronze.lineitem
INSERT INTO some_catalog.silver.lineitem
INSERT INTO some_catalog.bronze.nation
INSERT INTO some_catalog.silver.nation
INSERT INTO some_catalog.bronze.orders
INSERT INTO some_catalog.silver.orders
INSERT INTO some_catalog.bronze.part
INSERT INTO some_catalog.silver.part
INSERT INTO some_catalog.bronze.partsupp
INSERT INTO some_catalog.silver.partsupp
INSERT INTO some_catalog.bronze.region
INSERT INTO some_catalog.silver.region
INSERT INTO some_catalog.bronze.supplier
INSERT INTO some_catalog.silver.supplier
