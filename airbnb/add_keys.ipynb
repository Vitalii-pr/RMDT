# %%
# %sql
ALTER TABLE some_catalog.airbnb_silver.berlin_detailed_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_silver.berlin_detailed_listing
ADD PRIMARY KEY (id);

# %%
# %sql
ALTER TABLE some_catalog.airbnb_silver.berlin_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_silver.berlin_listing
ADD PRIMARY KEY (id);

# %%
# %sql
ALTER TABLE some_catalog.airbnb_silver.berlin_detailed_reviews
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_silver.berlin_detailed_reviews
ADD PRIMARY KEY (id);

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_silver.berlin_calendar
ADD CONSTRAINT fk_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_silver.berlin_listing(id)
""")

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_silver.berlin_detailed_reviews
ADD CONSTRAINT fk_det_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_silver.berlin_listing(id)
""")

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_silver.berlin_reviews
ADD CONSTRAINT fk_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_silver.berlin_listing(id)
""")

# %%
# %sql
ALTER TABLE some_catalog.airbnb_silver.stock_detailed_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_silver.stock_detailed_listing
ADD PRIMARY KEY (id);

# %%
# %sql
ALTER TABLE some_catalog.airbnb_silver.stock_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_silver.stock_listing
ADD PRIMARY KEY (id);

# %%
# %sql
ALTER TABLE some_catalog.airbnb_silver.stock_detailed_reviews
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_silver.stock_detailed_reviews
ADD PRIMARY KEY (id);

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_silver.stock_calendar
ADD CONSTRAINT fk_st_cal_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_silver.stock_listing(id)
""")

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_silver.stock_detailed_reviews
ADD CONSTRAINT fk_st_det_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_silver.stock_listing(id)
""")

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_silver.stock_review
ADD CONSTRAINT fk_st_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_silver.stock_listing(id)
""")

# %%
# %sql
ALTER TABLE some_catalog.airbnb_gold.berlin_detailed_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_gold.berlin_detailed_listing
ADD PRIMARY KEY (id);


ALTER TABLE some_catalog.airbnb_gold.berlin_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_gold.berlin_listing
ADD PRIMARY KEY (id);

ALTER TABLE some_catalog.airbnb_gold.berlin_detailed_reviews
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_gold.berlin_detailed_reviews
ADD PRIMARY KEY (id);

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_gold.berlin_calendar
ADD CONSTRAINT fk_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_gold.berlin_listing(id)
""")

spark.sql("""
ALTER TABLE some_catalog.airbnb_gold.berlin_detailed_reviews
ADD CONSTRAINT fk_det_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_gold.berlin_listing(id)
""")

spark.sql("""
ALTER TABLE some_catalog.airbnb_gold.berlin_reviews
ADD CONSTRAINT fk_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_gold.berlin_listing(id)
""")

# %%
# %sql
ALTER TABLE some_catalog.airbnb_gold.stock_detailed_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_gold.stock_detailed_listing
ADD PRIMARY KEY (id);

ALTER TABLE some_catalog.airbnb_gold.stock_listing
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_gold.stock_listing
ADD PRIMARY KEY (id);

ALTER TABLE some_catalog.airbnb_gold.stock_detailed_reviews
ALTER COLUMN id SET NOT NULL;

ALTER TABLE some_catalog.airbnb_gold.stock_detailed_reviews
ADD PRIMARY KEY (id);

# %%
spark.sql("""
ALTER TABLE some_catalog.airbnb_gold.stock_calendar
ADD CONSTRAINT fk_g_st_cal_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_gold.stock_listing(id)
""")

spark.sql("""
ALTER TABLE some_catalog.airbnb_gold.stock_detailed_reviews
ADD CONSTRAINT fk_g_st_det_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_gold.stock_listing(id)
""")

spark.sql("""
ALTER TABLE some_catalog.airbnb_gold.stock_review
ADD CONSTRAINT fk_g_st_rev_listing_id
FOREIGN KEY (listing_id)
REFERENCES some_catalog.airbnb_gold.stock_listing(id)
""")
