# %%
total_size = 0

for x in dbutils.fs.ls("/databricks-datasets/nyctaxi/tripdata/yellow/"):
    print(x.name, "-", round(x.size/(1024*1024)), "MB")
    total_size += x.size/(1024*1024)

print("Total size:", round(total_size), "MB")
